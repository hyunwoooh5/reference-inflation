# %%
import requests
import time
import json

# main category:
category = "nucl-th" # hep-lat
start_year=1995
end_year=2025
sample_per_year = 100

base_url = "https://inspirehep.net/api/literature"


# To get Number of papers
query = f"primary_arxiv_category:{category}"
params = {'q': query, 'size': sample_per_year, 'page':1}
response = requests.get(base_url, params)

all_samples = []


if response.status_code == 200:
    # Check number of papers
    data = response.json()
    total_hits = data['hits']['total']
    print(f"Number of papers in {category}: {total_hits}")


    # get sample_per_year papers for each year
    for year in range(start_year, end_year+1):
        print(f"year: {year}")

        query = f"primary_arxiv_category:{category} and year: {year}"


        params = {'q': query,
                  'size':sample_per_year,
                  'page':1,
                  'sort': 'random',
                  'seed': 42}

        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status() # except when error

            data = response.json()
            hits = data['hits']['hits']

            all_samples.extend(hits)
            print(f"{year} is done, until now: {len(all_samples)}")

            # To avoid overloading the server, add a short delay between request
            time.sleep(0.5)

        except requests.exceptions.RequestException as e:
            print(f"Error occurs during year {year}: {e}")
            break

else:
    print(f"Failed on initial API request: {response.status_code}")
    print(response.text)

# %%
# Need to remove duplicates because the above code might save different versions of the same paper.

print(f"Before removing duplicates: {len(all_samples)}")

unique_papers = []
seen_ids = set()

for paper in all_samples:
    paper_id = paper['id']
    if paper_id not in seen_ids:
        unique_papers.append(paper)
        seen_ids.add(paper_id)

print(f"After removing duplicates: {len(unique_papers)}")

# %%
with open('../data/data_nucl-th_100.json', 'w') as f:
   json.dump(unique_papers, f, ensure_ascii=False, indent=2)

# %% [markdown]
# # Import the data

# %%
import pandas as pd

df = pd.read_json("../data/data_nucl-th_100.json")

# %%
df.head()
# Out:
#         id                                              links  \
# 0  1459726  {'bibtex': 'https://inspirehep.net/api/literat...
# 1  1459842  {'bibtex': 'https://inspirehep.net/api/literat...
# 2  1460442  {'bibtex': 'https://inspirehep.net/api/literat...
# 3   392718  {'bibtex': 'https://inspirehep.net/api/literat...
# 4   397533  {'bibtex': 'https://inspirehep.net/api/literat...
#
#                             updated  \
# 0  2024-05-07T08:50:24.810153+00:00
# 1  2024-05-07T09:32:13.195422+00:00
# 2  2024-05-07T09:32:06.686143+00:00
# 3  2023-03-06T17:45:25.590277+00:00
# 4  2024-05-07T10:36:27.392018+00:00
#
#                                             metadata  \
# 0  {'publication_info': [{'journal_volume': '594'...
# 1  {'publication_info': [{'journal_volume': '351'...
# 2  {'publication_info': [{'journal_volume': '344'...
# 3  {'publication_info': [{'journal_volume': '340'...
# 4  {'publication_info': [{'journal_volume': '363'...
#
#                      created
# 0  2016-05-18T00:00:00+00:00
# 1  2016-05-18T00:00:00+00:00
# 2  2016-05-19T00:00:00+00:00
# 3  1995-02-14T00:00:00+00:00
# 4  1995-07-25T00:00:00+00:00

# %%
df.loc[0, 'metadata']
# Out:
# {'publication_info': [{'journal_volume': '594',
#    'page_end': '136',
#    'year': 1995,
#    'page_start': '117',
#    'journal_title': 'Nucl.Phys.A'}],
#  'citation_count_without_self_citations': 10,
#  'citation_count': 20,
#  'authors': [{'raw_affiliations': [{'value': "Departament d'Estructura i Constituents de la Matèria, Universitat de Barcelona, Diagonal 647, E-08028 Barcelona, Spain"}],
#    'full_name_unicode_normalized': 'polls, a.',
#    'full_name': 'Polls, A.',
#    'record': {'$ref': 'https://inspirehep.net/api/authors/1034953'},
#    'ids': [{'schema': 'INSPIRE BAI', 'value': 'A.Polls.1'}],
#    'last_name': 'Polls',
#    'signature_block': 'PALa',
#    'first_name': 'A.',
#    'uuid': '4c070c40-d8a6-4597-8319-0bff522901c4',
#    'recid': 1034953},
#   {'raw_affiliations': [{'value': 'Institut für Theoretische Physik, Universität Tübingen, Auf der Morgenstelle 14, D-72076 Tübingen, Germany'}],
#    'full_name_unicode_normalized': 'müther, h.',
#    'full_name': 'Müther, H.',
#    'record': {'$ref': 'https://inspirehep.net/api/authors/996373'},
#    'ids': [{'schema': 'INSPIRE BAI', 'value': 'H.Muether.1'}],
#    'last_name': 'Müther',
#    'signature_block': 'MATARh',
#    'first_name': 'H.',
#    'uuid': '4bd0ccce-548c-4f5f-aa0d-deb8562a4620',
#    'recid': 996373},
#   {'raw_affiliations': [{'value': 'Department of Physics, Washington University, St. Louis, MO 63130, USA'}],
#    'full_name_unicode_normalized': 'dickhoff, w.h.',
#    'full_name': 'Dickhoff, W.H.',
#    'record': {'$ref': 'https://inspirehep.net/api/authors/1034054'},
#    'ids': [{'schema': 'INSPIRE BAI', 'value': 'W.H.Dickhoff.1'}],
#    'last_name': 'Dickhoff',
#    'signature_block': 'DACAFw',
#    'first_name': 'W.H.',
#    'uuid': '62ff30cb-34e2-4a41-bab5-5e855d60cbbf',
#    'recid': 1034054}],
#  'report_numbers': [{'value': 'TU-95-0328'}],
#  'citeable': True,
#  'copyright': [{'statement': 'Copyright @ unknown. Published by Elsevier B.V.'}],
#  '$schema': 'https://inspirehep.net/schemas/records/hep.json',
#  'references': [{'reference': {'label': '1',
#     'publication_info': {'journal_volume': '158',
#      'artid': '103',
#      'year': 1985,
#      'page_start': '103',
#      'journal_title': 'Phys.Lett.B'},
#     'authors': [{'full_name': 'Jaminon, M.'},
#      {'full_name': 'Mahaux, C.'},
#      {'full_name': 'Ngô, H.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1451003'}},
#   {'reference': {'label': '2',
#     'publication_info': {'journal_volume': '553',
#      'artid': '297c',
#      'year': 1993,
#      'page_start': '297c',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Lapikas, L.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/642004'}},
#   {'reference': {'label': '3',
#     'publication_info': {'journal_volume': '73',
#      'artid': '2684',
#      'year': 1994,
#      'page_start': '2684',
#      'journal_title': 'Phys.Rev.Lett.'},
#     'authors': [{'full_name': 'Bobeldijk, I.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/391901'}},
#   {'reference': {'label': '4',
#     'publication_info': {'journal_volume': '344',
#      'artid': '85',
#      'year': 1995,
#      'page_start': '85',
#      'journal_title': 'Phys.Lett.B'},
#     'authors': [{'full_name': 'Blomqvist, K.I.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/406540'}},
#   {'reference': {'label': '5',
#     'publication_info': {'journal_volume': '86',
#      'artid': '671',
#      'year': 1991,
#      'page_start': '671',
#      'journal_title': 'Prog.Theor.Phys.'},
#     'authors': [{'full_name': 'Morita, H.'}, {'full_name': 'Suzuki, T.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/316618'}},
#   {'reference': {'label': '6',
#     'publication_info': {'journal_volume': '141',
#      'artid': '14',
#      'year': 1984,
#      'page_start': '14',
#      'journal_title': 'Phys.Lett.B'},
#     'authors': [{'full_name': 'Ciofi degli Atti, C.'},
#      {'full_name': 'Pace, E.'},
#      {'full_name': 'Salmè, G.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1450173'}},
#   {'reference': {'label': '7',
#     'publication_info': {'journal_volume': '47',
#      'artid': '2218',
#      'year': 1993,
#      'page_start': '2218',
#      'journal_title': 'Phys.Rev.C'},
#     'authors': [{'full_name': 'Benhar, O.'},
#      {'full_name': 'Pandharipande, V.R.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/362358'}},
#   {'reference': {'label': '8',
#     'publication_info': {'journal_volume': '46',
#      'artid': '1741',
#      'year': 1992,
#      'page_start': '1741',
#      'journal_title': 'Phys.Rev.C'},
#     'authors': [{'full_name': 'Pieper, S.C.'},
#      {'full_name': 'Wiringa, R.B.'},
#      {'full_name': 'Pandharipande, V.R.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/349582'}},
#   {'reference': {'label': '9',
#     'publication_info': {'journal_volume': '256',
#      'artid': '1',
#      'year': 1991,
#      'page_start': '1',
#      'journal_title': 'Phys.Lett.B'},
#     'authors': [{'full_name': 'Ma, Z.Y.'}, {'full_name': 'Wambach, J.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1458134'}},
#   {'reference': {'label': '10',
#     'publication_info': {'journal_volume': '20',
#      'artid': '1',
#      'year': 1991,
#      'page_start': '1',
#      'journal_title': 'Adv.Nucl.Phys.'},
#     'authors': [{'full_name': 'Mahaux, C.'}, {'full_name': 'Sartor, R.'}]}},
#   {'reference': {'label': '11',
#     'publication_info': {'journal_volume': '503',
#      'artid': '1',
#      'year': 1989,
#      'page_start': '1',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Ramos, A.'},
#      {'full_name': 'Polls, A.'},
#      {'full_name': 'Dickhoff, W.H.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1456583'}},
#   {'reference': {'label': '12',
#     'publication_info': {'journal_volume': '505',
#      'artid': '267',
#      'year': 1989,
#      'page_start': '267',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Benhar, O.'},
#      {'full_name': 'Fabrocini, A.'},
#      {'full_name': 'Fantoni, S.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/288050'}},
#   {'reference': {'label': '13',
#     'publication_info': {'journal_volume': '44',
#      'artid': 'R7',
#      'year': 1991,
#      'page_start': 'R7',
#      'journal_title': 'Phys.Rev.C'},
#     'authors': [{'full_name': 'Ciofi degli Atti, C.'},
#      {'full_name': 'Simula, S.'},
#      {'full_name': 'Frankfurt, L.L.'},
#      {'full_name': 'Strikman, M.I.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/323176'}},
#   {'reference': {'label': '14',
#     'publication_info': {'journal_volume': '555',
#      'artid': '1',
#      'year': 1993,
#      'page_start': '1',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Vonderfecht, B.E.'},
#      {'full_name': 'Dickhoff, W.H.'},
#      {'full_name': 'Polls, A.'},
#      {'full_name': 'Ramos, A.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1459988'}},
#   {'reference': {'label': '15',
#     'misc': ['to be published'],
#     'authors': [{'full_name': 'Gearhart, C.C.'},
#      {'full_name': 'Dickhoff, W.H.'},
#      {'full_name': 'Polls, A.'},
#      {'full_name': 'Ramos, A.'}]}},
#   {'reference': {'label': '16',
#     'publication_info': {'journal_volume': '41',
#      'artid': '1748',
#      'year': 1990,
#      'page_start': '1748',
#      'journal_title': 'Phys.Rev.C'},
#     'authors': [{'full_name': 'Baldo, M.'},
#      {'full_name': 'Bombaci, I.'},
#      {'full_name': 'Giansiracusa, G.'},
#      {'full_name': 'Lombardo, U.'},
#      {'full_name': 'Mahaux, C.'},
#      {'full_name': 'Sartor, R.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/313007'}},
#   {'reference': {'label': '17',
#     'publication_info': {'journal_volume': '537',
#      'artid': '64',
#      'year': 1992,
#      'page_start': '64',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Köhler, H.S.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1458722'}},
#   {'reference': {'label': '18',
#     'publication_info': {'journal_volume': '516',
#      'artid': '33',
#      'year': 1990,
#      'page_start': '33',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Stringari, S.'},
#      {'full_name': 'Traini, M.'},
#      {'full_name': 'Bohigas, O.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1457169'}},
#   {'reference': {'label': '19',
#     'publication_info': {'journal_volume': '323',
#      'artid': '267',
#      'year': 1994,
#      'page_start': '267',
#      'journal_title': 'Phys.Lett.B'},
#     'authors': [{'full_name': 'Sick, I.'},
#      {'full_name': 'Fantoni, A.'},
#      {'full_name': 'Fabrocini, A.'},
#      {'full_name': 'Benhar, O.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/378726'}},
#   {'reference': {'label': '20',
#     'publication_info': {'journal_volume': '579',
#      'artid': '493',
#      'year': 1994,
#      'page_start': '493',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Benhar, O.'},
#      {'full_name': 'Fabrocini, A.'},
#      {'full_name': 'Fantoni, S.'},
#      {'full_name': 'Sick, I.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/384576'}},
#   {'reference': {'label': '21',
#     'publication_info': {'year': 1994},
#     'misc': ['preprint'],
#     'authors': [{'full_name': 'Van Neck, D.'},
#      {'full_name': 'Dieperink, A.E.L.'},
#      {'full_name': 'de Guerra, E. Moya'}]}},
#   {'reference': {'label': '22',
#     'publication_info': {'journal_volume': '97',
#      'artid': '1474',
#      'year': 1955,
#      'page_start': '1474',
#      'journal_title': 'Phys.Rev.'},
#     'authors': [{'full_name': 'Löwdin, P.-O.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/47392'}},
#   {'reference': {'imprint': {'publisher': 'Clarendon Press Oxford'},
#     'label': '23',
#     'publication_info': {'year': 1988},
#     'title': {'title': 'Nucleon Momentum and Density Distributions in Nuclei'},
#     'authors': [{'full_name': 'Antonov, A.N.'},
#      {'full_name': 'Hodgson, P.E.'},
#      {'full_name': 'Petkov'},
#      {'full_name': 'I.Zh.'}]}},
#   {'reference': {'label': '24',
#     'publication_info': {'journal_volume': '48',
#      'artid': '74',
#      'year': 1994,
#      'page_start': '74',
#      'journal_title': 'Phys.Rev.C'},
#     'authors': [{'full_name': 'Stoitsov, M.V.'},
#      {'full_name': 'Antonov, A.N.'},
#      {'full_name': 'Dimitrova, S.S.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/370470'}},
#   {'reference': {'label': '25',
#     'publication_info': {'journal_volume': '314',
#      'artid': '255',
#      'year': 1993,
#      'page_start': '255',
#      'journal_title': 'Phys.Lett.B'},
#     'authors': [{'full_name': 'Van Neck, D.'},
#      {'full_name': 'Waroquier, M.'},
#      {'full_name': 'Heyde, K.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1459373'}},
#   {'reference': {'label': '26',
#     'publication_info': {'journal_volume': '49',
#      'artid': 'R17',
#      'year': 1994,
#      'page_start': 'R17',
#      'journal_title': 'Phys.Rev.C'},
#     'authors': [{'full_name': 'Müther, H.'}, {'full_name': 'Dickhoff, W.H.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/357282'}},
#   {'reference': {'label': '27',
#     'misc': ['Phys. Rev. in print'],
#     'authors': [{'full_name': 'Müther, H.'},
#      {'full_name': 'Polls, A.'},
#      {'full_name': 'Dickhoff, W.H.'}]}},
#   {'reference': {'label': '28',
#     'publication_info': {'journal_volume': '19',
#      'artid': '1',
#      'year': 1989,
#      'page_start': '1',
#      'journal_title': 'Adv.Nucl.Phys.'},
#     'authors': [{'full_name': 'Machleidt, R.'}]}},
#   {'reference': {'label': '29',
#     'publication_info': {'journal_volume': '55',
#      'artid': '1947',
#      'year': 1992,
#      'page_start': '1947',
#      'journal_title': 'Rept.Prog.Phys.'},
#     'authors': [{'full_name': 'Dickhoff, W.H.'}, {'full_name': 'Müther, H.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/346806'}},
#   {'reference': {'label': '30',
#     'publication_info': {'journal_volume': '496',
#      'artid': '23',
#      'year': 1989,
#      'page_start': '23',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Bonatsos, D.'}, {'full_name': 'Müther, H.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1456309'}},
#   {'reference': {'label': '31',
#     'publication_info': {'journal_volume': '183',
#      'artid': '210',
#      'year': 1972,
#      'page_start': '210',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Wong, C.W.'}, {'full_name': 'Clement, D.M.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1440777'}},
#   {'reference': {'label': '32',
#     'publication_info': {'journal_volume': '530',
#      'artid': '14',
#      'year': 1991,
#      'page_start': '14',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Schmid, K.W.'},
#      {'full_name': 'Müther, H.'},
#      {'full_name': 'Machleidt, R.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/321144'}},
#   {'reference': {'label': '33',
#     'publication_info': {'journal_volume': '17',
#      'artid': '97',
#      'year': 1986,
#      'page_start': '97',
#      'journal_title': 'Prog.Part.Nucl.Phys.'},
#     'authors': [{'full_name': 'Müther, H.'}]},
#    'record': {'$ref': 'https://inspirehep.net/api/literature/241485'}},
#   {'reference': {'label': '34',
#     'publication_info': {'journal_volume': '539',
#      'artid': '189',
#      'year': 1992,
#      'page_start': '189',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Borromeo, M.'},
#      {'full_name': 'Bonatsos, D.'},
#      {'full_name': 'Müther, H.'},
#      {'full_name': 'Polls, A.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1458593'}},
#   {'reference': {'label': '35',
#     'publication_info': {'journal_volume': '531',
#      'artid': '253',
#      'year': 1991,
#      'page_start': '253',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Brand, M.G.E.'},
#      {'full_name': 'Rijsdijk, G.A.'},
#      {'full_name': 'Muller, F.A.'},
#      {'full_name': 'Allaart, K.'},
#      {'full_name': 'Dickhoff, W.H.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1457707'}},
#   {'reference': {'label': '36',
#     'publication_info': {'journal_volume': '550',
#      'artid': '159',
#      'year': 1992,
#      'page_start': '159',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Rijsdijk, G.A.'},
#      {'full_name': 'Allaart, K.'},
#      {'full_name': 'Dickhoff, W.H.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1458823'}},
#   {'reference': {'label': '37',
#     'publication_info': {'journal_volume': '306',
#      'artid': '306',
#      'year': 1993,
#      'page_start': '306',
#      'journal_title': 'Phys.Lett.B'},
#     'authors': [{'full_name': 'Müther, H.'}, {'full_name': 'Skouras, L.D.'}]}},
#   {'reference': {'label': '38',
#     'publication_info': {'journal_volume': '581',
#      'artid': '247',
#      'year': 1995,
#      'page_start': '247',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Müther, H.'}, {'full_name': 'Skouras, L.D.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/359219'}},
#   {'reference': {'label': '39',
#     'publication_info': {'journal_volume': '37',
#      'artid': '4950',
#      'year': 1988,
#      'page_start': '4950',
#      'journal_title': 'Phys.Rev.B'},
#     'authors': [{'full_name': 'Lewart, D.S.'},
#      {'full_name': 'Pandharipande, V.R.'},
#      {'full_name': 'Pieper, S.C.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/276334'}},
#   {'reference': {'label': '40',
#     'publication_info': {'journal_volume': '568',
#      'artid': '73',
#      'year': 1994,
#      'page_start': '73',
#      'journal_title': 'Nucl.Phys.A'},
#     'authors': [{'full_name': 'Có, G.'},
#      {'full_name': 'Fabrocini, A.'},
#      {'full_name': 'Fantoni, S.'}]},
#    'curated_relation': False,
#    'record': {'$ref': 'https://inspirehep.net/api/literature/1460392'}},
#   {'reference': {'label': '41',
#     'publication_info': {'year': 1995},
#     'misc': ['preprint'],
#     'authors': [{'full_name': 'Müther, H.'},
#      {'full_name': 'Knehr, G.'},
#      {'full_name': 'Polls, A.'}]}}],
#  'number_of_pages': 20,
#  'legacy_creation_date': '2016-05-18',
#  'preprint_date': '1995-03-28',
#  'author_count': 3,
#  'public_notes': [{'source': 'arXiv',
#    'value': '13 pages, RevTeX, 5 figures added'}],
#  'earliest_date': '1995-03-28',
#  'refereed': True,
#  'external_system_identifiers': [{'schema': 'NSR', 'value': '1995PO13'}],
#  'facet_author_name': ['996373_Herbert Müther',
#   '1034054_Willem H. Dickhoff',
#   '1034953_Artur Polls'],
#  'journal_title_variants': ['Nucl. Phys. A', 'Nucl.Phys.A'],
#  'arxiv_eprints': [{'categories': ['nucl-th'], 'value': 'nucl-th/9503025'}],
#  'referenced_authors_bais': ['K.Allaart.3',
#   'M.N.Harakeh.1',
#   'R.Bohm.1',
#   'G.Rosner.1',
#   'A.Rokavec.2',
#   'J.J.van.Leeuwe.1',
#   'R.M.De.Vries.1',
#   'J.Wambach.1',
#   'R.B.Wiringa.1',
#   'F.A.Muller.1',
#   'Axel.Wagner.1',
#   'P.K.A.de.WittHuberts.1',
#   'J.J.M.Steijger.1',
#   'O.Bohigas.1',
#   'K.I.Blomqvist.2',
#   'R.Machleidt.1',
#   'G.Salme.1',
#   'B.E.Vonderfecht.1',
#   'E.Passchier.1',
#   'R.Geiges.1',
#   'U.Lombardo.1',
#   'J.J.Kelly.1',
#   'M.Schroevers.2',
#   'C.Ciofi.degli.Atti.1',
#   'M.V.Stoitsov.2',
#   'M.Bouwhuis.1',
#   'L.D.Skouras.1',
#   'R.Neuhausen.1',
#   'M.Kuss.1',
#   'M.Traini.1',
#   'D.Van.Neck.6',
#   'R.Sartor.2',
#   'H.P.Blok.16',
#   'S.Simula.1',
#   'Hilding.Sigurd.Kohler.1',
#   'J.Konijn.1',
#   'A.Liesenfeld.2',
#   'S.Fantoni.1',
#   'M.A.van.Uden.1',
#   'M.Jaminon.6',
#   'V.Kunde.2',
#   'I.Bobeldijk.1',
#   'A.Serdarevic.2',
#   'H.Ngo.3',
#   'T.Pospischil.3',
#   'M.Potokar.14',
#   'W.J.Kasdorp.1',
#   'J.Lac.1',
#   'M.Waroquier.1',
#   'A.Polls.1',
#   'G.van.der.Steenhoven.38',
#   'A.N.Antonov.1',
#   'A.Richter.2',
#   'Zhong.Yu.Ma.1',
#   'N.de.Jonge.1',
#   'M.Baldo.2',
#   'D.M.Clement.1',
#   'P.O.Lowdin.1',
#   'H.Muether.1',
#   'W.H.Dickhoff.1',
#   'W.H.A.Hesselink.15',
#   'Angels.Ramos.1',
#   'C.Marchand.2',
#   'R.L.J.van.der.Meer.3',
#   'M.O.Distler.1',
#   'D.Bonatsos.1',
#   'J.A.Templon.3',
#   'L.L.Frankfurt.1',
#   'M.Korn.7',
#   'G.Nooren.1',
#   'P.U.Sauer.1',
#   'W.U.Boeglin.1',
#   'J.A.P.Theunissen.1',
#   'C.M.Spaltro.1',
#   'G.Giansiracusa.1',
#   'E.Jans.2',
#   'D.S.Lewart.1',
#   'J.Friedrich.1',
#   'L.Lapikas.1',
#   'S.C.Pieper.1',
#   'M.G.E.Brand.1',
#   'H.B.van.den.Brink.1',
#   'M.Strikman.1',
#   'T.Veit.1',
#   'N.Kalantar.Nayestanaki.1',
#   'S.Stringari.1',
#   'D.G.Ireland.1',
#   'V.R.Pandharipande.1',
#   'S.Wolf.2',
#   'I.Bombaci.1',
#   'S.S.Dimitrova.1',
#   'Claude.Mahaux.1',
#   'A.Pellegrino.1',
#   'A.Fabrocini.1',
#   'K.Merle.4',
#   'G.E.Dodge.1',
#   'T.Suzuki.20',
#   'R.S.Hicks.6',
#   'H.Morita.1',
#   'E.A.J.M.Offermann.1',
#   'H.Kramer.2',
#   'H.de.Vries.1',
#   'E.Pace.1',
#   'K.W.Schmid.7',
#   'O.Benhar.1',
#   'G.A.Rijsdijk.1',
#   'M.Borromeo.1',
#   'M.Kahrau.1',
#   'G.Co.1',
#   'Chun.Wing.Wong.1',
#   'B.Vodenik.2',
#   'T.Walcher.1',
#   'S.Schardt.4',
#   'K.W.Krygier.1',
#   'I.Sick.1',
#   'K.Heyde.1',
#   'R.Edelhoff.2',
#   'C.W.de.Jager.1'],
#  'legacy_version': '20170222095952.0',
#  'inspire_categories': [{'term': 'Theory-Nucl', 'source': 'magpie'}],
#  'first_author': {'full_name': 'Polls, A.',
#   'last_name': 'Polls',
#   'first_name': 'A.',
#   'recid': 1034953},
#  'control_number': 1459726,
#  'dois': [{'source': 'Elsevier', 'value': '10.1016/0375-9474(95)00380-J'}],
#  'document_type': ['article'],
#  'texkeys': ['Polls:1995hkz'],
#  'abstracts': [{'source': 'Elsevier',
#    'value': 'The effects of short-range correlations derived from a realistic meson-exchange potential on the single-particle density matrix in finite nuclei are investigated by analyzing the one-body density in terms of the natural orbits. Basic features of these natural orbits and their spectral distributions are discussed. For many observables it seems to be sufficient to approximate the one-body density matrix in terms of those natural orbits, which exhibit the largest occupation probabilities. For the investigation of the high-momentum components in the single-particle density, however, it is important to take into account natural orbits with small occupation probabilities, originating from the single-particle Green function at large negative energies.',
#    'abstract_source_suggest': {'input': 'Elsevier'}},
#   {'source': 'arXiv',
#    'value': 'The effects of short-range correlations derived from a realistic meson-exchange potential on the single-particle density matrix in finite nuclei are investigated by analyzing the one-body density in terms of the natural orbits. Basic features of these natural orbits and their spectral distributions are discussed. For many observables it seems to be sufficient to approximate the one-body density matrix in terms of those natural orbits, which exhibit the largest occupation probabilities. For the investigation of the high-momentum components in the single-particle density, however, it is important to take into account natural orbits with small occupation probabilities, originating from the single-particle Green function at large negative energies.',
#    'abstract_source_suggest': {'input': 'arXiv'}}],
#  'primary_arxiv_category': ['nucl-th'],
#  'titles': [{'title': 'Short-range correlations and the one-body density matrix in finite nuclei'},
#   {'source': 'arXiv',
#    'title': 'Short-Range Correlations and the One-Body Density Matrix in Finite Nuclei'}],
#  'imprints': [{'date': '1995'}],
#  'curated': False}
